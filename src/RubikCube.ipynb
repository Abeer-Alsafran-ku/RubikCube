# %%
cd ~/
# Out:
# /root

# %%
# !git clone https://github.com/dwalton76/rubiks-cube-NxNxN-solver.git
# Out:
# Cloning into 'rubiks-cube-NxNxN-solver'...
# remote: Enumerating objects: 5515, done.
# remote: Counting objects: 100% (565/565), done.
# remote: Compressing objects: 100% (270/270), done.
# remote: Total 5515 (delta 420), reused 402 (delta 295), pack-reused 4950 (from 1)
# Receiving objects: 100% (5515/5515), 34.34 MiB | 13.52 MiB/s, done.
# Resolving deltas: 100% (4131/4131), done.

# %%
cd rubiks-cube-NxNxN-solver
# Out:
# /root/rubiks-cube-NxNxN-solver

# %%
# !make init
# Out:
# rm -rf build dist venv rubikscubennnsolver.egg-info cache ida_search ida_search_via_graph my-pt-states.txt
# find . -name __pycache__ | xargs rm -rf
# gcc -O3 -o ida_search_via_graph rubikscubennnsolver/ida_search_core.c rubikscubennnsolver/rotate_xxx.c rubikscubennnsolver/ida_search_666.c rubikscubennnsolver/ida_search_777.c rubikscubennnsolver/ida_search_via_graph.c -lm
# python3 -m venv venv
# Error: Command '['/root/rubiks-cube-NxNxN-solver/venv/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# make: *** [Makefile:8: init] Error 1
